# %% [markdown]
# # Introduction to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#0 import matplotlib and get it ready for use in jupyter
# %matplotlib inline
import matplotlib.pyplot as plt
 
#1 Prepare data
x = [5,10,30,40,50]
y = [11,15,20,35, 45]

#2 Setup Plot
Fig, ax = plt.subplots(figsize=(8,8))

#3 Plot data
ax.plot(x,y)

#4 Customise Plot
ax.set(title='Bal Plot',
      xlabel= 'x-axis',
      ylabel= 'y-axis')

#5 Save and show Figure
fig.savefig("images/sample-plot.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-018e19da880a> in <module>
#      19
#      20 #5 Save and show Figure
# ---> 21 fig.savefig("images/sample-plot.png")
#
# NameError: name 'fig' is not defined

# %% [markdown]
# ## Making Figures with Numpy Array

# %%
import numpy as np
